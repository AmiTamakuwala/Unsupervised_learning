# %% [markdown]
# ## Testing MPL_toolkits for geographical plot:

# %%
import mpl_toolkits

# %%
from mpl_toolkits.basemap import Basemap

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap()

map.drawcoastlines()

plt.show()
plt.savefig('test_coastlines.png')

# %%
#creating plot for the mapboundries and fill the color in continents:

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='ortho',
             lat_0 = 0, lon_0 = 0)

# Fill the globe with a blue color:

map.drawmapboundary(fill_color='skyblue')

# Fill the continents with the land color:

map.fillcontinents(color = 'coral', lake_color = 'aqua')

map.drawcoastlines()

plt.show()

# %%
# creating plot for 'map boundries', 'continents', 'continents'


from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='cyl')

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral', lake_color='blue')
map.drawcoastlines()

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))

map = Basemap(projection='ortho',
             lat_0 = 0, lon_0 = 0)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='green', lake_color='blue')
map.drawcoastlines()
map.drawcounties()
x, y = map(0, 0)

map.plot(x, y, marker='D', color='m')

plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
map = Basemap(projection='ortho',
             lat_0 = 0, lon_0 = 0)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='green', lake_color='skyblue')
map.drawcoastlines()

lons = [0, 10, -20, -20]
lats = [0, -10, 40, -20]

x, y = map(lons, lats)

map.scatter(x,y, marker = 'D', color = 'm')

plt.show()
plt.close()
